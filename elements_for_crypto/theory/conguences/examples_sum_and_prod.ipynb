# %% [markdown]
# Se quiere mostrar graficamente las operaciones de suma y producto en aritmética de residuos

# %%
import networkx as nt
import matplotlib.pyplot as plt
import sympy.ntheory as nt
from gtools_congs import *

# %%
g13 = gclasses_mod(13)
# gsum_mod(13, 9,11)
gprod_mod(13, 5, 4)

plt.show()
